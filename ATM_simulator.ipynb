# %% [markdown]
# <a href="https://colab.research.google.com/github/Esmail97/rpython/blob/main/ATM_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ATM simulation
balance = 1000
user_pin = '1234'
print('Welcome to the ATM simulator!')
entered_pin = input('Enter your PIN:)')
if entered_pin != user_pin:
    print('Wrong PIN!')
    atm_on = False
else:
    atm_on = True
while atm_on:
  print('Main Menu')
  print('1. Check Balance')
  print('2. Deposit')
  print('3. Withdraw')
  print('4. Exit')
  user_choice = input('Enter your choice: ')
  if user_choice == '1':
    print('Your balance is $: ', str(balance))
  elif user_choice == '2':
    deposit_amount = float(input('Enter the amount to deposit: '))
    balance += deposit_amount
    print("$" + str(deposit_amount) + " deposited successfully.")
  elif user_choice == '3':
    withdraw_amount = float(input('Enter the amount to withdraw: '))
    if withdraw_amount > balance:
      print("Insufficient balance.")
    else:
      balance -= withdraw_amount
      print("$" + str(withdraw_amount) + " withdrawn successfully.")
  elif user_choice == '4':
        print("Thank you for using the ATM. Goodbye!")
        atm_on = False

  else:
        print("Invalid choice. Please try again.")
# Out:
# Welcome to the ATM simulator!
# Enter your PIN:)1234
# Main Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 1
# Your balance is $:  1000
# Main Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 2
# Enter the amount to deposit: 50
# $50.0 deposited successfully.
# Main Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 3
# Enter the amount to withdraw: 500
# $500.0 withdrawn successfully.
# Main Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 4
# Thank you for using the ATM. Goodbye!
